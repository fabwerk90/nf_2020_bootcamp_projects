# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ##### setup and loading data

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_fp = pd.read_csv("data/fp_data.csv", index_col=0)
df_gk = pd.read_csv("data/gk_data.csv", index_col=0)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ##### look at variables and data structure

# %%
df_fp.dtypes
# Out:
# market_value_€                   float64
# player_name                       object
# long_name                         object
# year_of_birth                      int64
# player_age                         int64
# height_cm                          int64
# weight_kg                          int64
# nationality                       object
# main_position                     object
# all_positions                     object
# club                              object
# league                            object
# divison                            int64
# national_team_current_or_past      int64
# national_team_country             object
# current_national_player            int64
# no_current_national_player         int64
# national_team_appearances          int64
# international_reputation           int64
# overall                            int64
# potential                          int64
# preferred_foot                    object
# weak_foot                          int64
# skill_moves                        int64
# work_rate                         object
# pace                               int64
# shooting                           int64
# passing                            int64
# dribbling                          int64
# defending                          int64
#                                   ...
# mentality_composure                int64
# defending_marking                  int64
# defending_standing_tackle          int64
# defending_sliding_tackle           int64
# ls                                 int64
# st                                 int64
# rs                                 int64
# lw                                 int64
# lf                                 int64
# cf                                 int64
# rf                                 int64
# rw                                 int64
# lam                                int64
# cam                                int64
# ram                                int64
# lm                                 int64
# lcm                                int64
# cm                                 int64
# rcm                                int64
# rm                                 int64
# lwb                                int64
# ldm                                int64
# cdm                                int64
# rdm                                int64
# rwb                                int64
# lb                                 int64
# lcb                                int64
# cb                                 int64
# rcb                                int64
# rb                                 int64
# Length: 87, dtype: object

# %%
df_gk.dtypes
# Out:
# market_value_€                   float64
# player_name                       object
# long_name                         object
# year_of_birth                      int64
# player_age                         int64
# height_cm                          int64
# weight_kg                          int64
# nationality                       object
# main_position                     object
# club                              object
# league                            object
# divison                            int64
# national_team_current_or_past      int64
# national_team_country             object
# current_national_player            int64
# no_current_national_player         int64
# national_team_appearances          int64
# international_reputation           int64
# overall                            int64
# potential                          int64
# preferred_foot                    object
# weak_foot                          int64
# skill_moves                        int64
# gk_diving                          int64
# gk_handling                        int64
# gk_kicking                         int64
# gk_reflexes                        int64
# gk_speed                           int64
# gk_positioning                     int64
# player_traits                     object
# attacking_short_passing            int64
# skill_long_passing                 int64
# skill_ball_control                 int64
# movement_acceleration              int64
# movement_sprint_speed              int64
# movement_agility                   int64
# movement_reactions                 int64
# movement_balance                   int64
# power_shot_power                   int64
# power_jumping                      int64
# power_stamina                      int64
# power_strength                     int64
# mentality_aggression               int64
# mentality_vision                   int64
# mentality_composure                int64
# goalkeeping_diving                 int64
# goalkeeping_handling               int64
# goalkeeping_kicking                int64
# goalkeeping_positioning            int64
# goalkeeping_reflexes               int64
# dtype: object

# %%
# show numbers with 3 decimal places
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df_fp.head()
# Out:
#    market_value_€        player_name                            long_name  \
# 0   112000000.000       Lionel Messi       Lionel Andrés Messi Cuccittini
# 1    60000000.000  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 2   128000000.000             Neymar        Neymar da Silva Santos Junior
# 3    80000000.000        Eden Hazard                          Eden Hazard
# 4   120000000.000    Kevin De Bruyne                      Kevin De Bruyne
#
#    year_of_birth  player_age  height_cm  weight_kg nationality  \
# 0           1987          32        170         72   Argentina
# 1           1985          35        187         83    Portugal
# 2           1992          28        175         68      Brazil
# 3           1991          28        175         74     Belgium
# 4           1991          28        181         70     Belgium
#
#            main_position all_positions                    club  \
# 0            Rechtsaußen    RW, CF, ST            FC Barcelona
# 1             Linksaußen        ST, LW          Juventus Turin
# 2             Linksaußen       LW, CAM  FC Paris Saint-Germain
# 3             Linksaußen        LW, CF             Real Madrid
# 4  Offensives Mittelfeld       CAM, CM         Manchester City
#
#            league  divison  national_team_current_or_past  \
# 0          LaLiga        1                              1
# 1         Serie A        1                              1
# 2         Ligue 1        1                              1
# 3          LaLiga        1                              1
# 4  Premier League        1                              1
#
#   national_team_country  current_national_player  no_current_national_player  \
# 0           Argentinien                        1                           0
# 1              Portugal                        1                           0
# 2             Brasilien                        1                           0
# 3               Belgien                        1                           0
# 4               Belgien                        1                           0
#
#    national_team_appearances  international_reputation  overall  potential  \
# 0                        138                         5       94         94
# 1                        164                         5       93         93
# 2                        102                         5       92         92
# 3                        106                         4       91         91
# 4                         74                         4       91         91
#
#   preferred_foot  weak_foot  skill_moves    work_rate  pace  shooting  \
# 0           Left          4            4   Medium/Low    87        92
# 1          Right          4            5     High/Low    90        93
# 2          Right          5            5  High/Medium    91        85
# 3          Right          4            4  High/Medium    91        83
# 4          Right          5            4    High/High    76        86
#
#    passing  dribbling  defending  physic  \
# 0       92         96         39      66
# 1       82         89         35      78
# 2       87         95         32      58
# 3       86         94         35      66
# 4       92         86         61      78
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
# 1  Long Throw-in, Selfish, Argues with Officials,...                  84
# 2  Power Free-Kick, Injury Free, Selfish, Early C...                  87
# 3  Beat Offside Trap, Selfish, Finesse Shot, Spee...                  81
# 4  Power Free-Kick, Avoids Using Weaker Foot, Div...                  93
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
# 1                   94                          89                       83
# 2                   87                          62                       87
# 3                   84                          61                       89
# 4                   82                          55                       92
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 88               97           93                 94
# 1                 87               89           81                 76
# 2                 87               96           88                 87
# 3                 83               95           83                 79
# 4                 82               86           85                 83
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  92                  96                     91
# 1                  77                  92                     89
# 2                  81                  95                     94
# 3                  83                  94                     94
# 4                  91                  91                     77
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
# 1                     91                87                  96
# 2                     89                96                  92
# 3                     88                95                  90
# 4                     76                78                  91
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
# 1                71                95             95             85
# 2                84                80             61             81
# 3                94                82             56             84
# 4                76                91             63             89
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
# 1              78                93                    63
# 2              49                84                    51
# 3              63                80                    54
# 4              74                90                    76
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
# 1                       29                     95                82
# 2                       36                     87                90
# 3                       41                     87                89
# 4                       61                     88                94
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
# 1                   85                   95                 28
# 2                   90                   94                 27
# 3                   88                   91                 34
# 4                   79                   91                 68
#
#    defending_standing_tackle  defending_sliding_tackle  ls  st  rs  lw  lf  \
# 0                         37                        26  89  89  89  93  93
# 1                         32                        24  91  91  91  89  90
# 2                         26                        29  84  84  84  90  89
# 3                         27                        22  83  83  83  89  88
# 4                         58                        51  82  82  82  87  87
#
#    cf  rf  rw  lam  cam  ram  lm  lcm  cm  rcm  rm  lwb  ldm  cdm  rdm  rwb  \
# 0  93  93  93   93   93   93  92   87  87   87  92   68   66   66   66   68
# 1  90  90  89   88   88   88  88   81  81   81  88   65   61   61   61   65
# 2  89  89  90   90   90   90  89   82  82   82  89   66   61   61   61   66
# 3  88  88  89   89   89   89  89   83  83   83  89   66   63   63   63   66
# 4  87  87  87   88   88   88  88   87  87   87  88   77   77   77   77   77
#
#    lb  lcb  cb  rcb  rb
# 0  63   52  52   52  63
# 1  61   53  53   53  61
# 2  61   46  46   46  61
# 3  61   49  49   49  61
# 4  73   66  66   66  73

# %% [markdown]
# ##### build plotting function for histograms

# %%
def plot_hist(df, feature, title):
    
    feature_mean = round(df[f"{feature}"].mean()).astype("int64")

    plt.figure(figsize=(15,5))

    ax = sns.distplot(df[f"{feature}"], bins = 20, kde=False)

    plt.ticklabel_format(style='plain', axis='x')
    ax.tick_params(labelsize=14)
    ax.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
    
    plt.axvline(feature_mean, color='b', linestyle='dashed', linewidth=2, ymax=0.95, label="Mean")

    ax.set_ylabel("count", fontsize = 16)
    ax.set_xlabel(f"{feature}", fontsize = 16)
    ax.set_title(f"{title}",fontsize = 20)
    
    ### text box, for fast visualisation of key values
    
    # defining key values for texr box
    min_value = round(df[f"{feature}"].min()).astype("int64")
    max_value = round(df[f"{feature}"].max()).astype("int64")
    mean_value = round(df[f"{feature}"].mean()).astype("int64")
    
    # put key values in joined text-string
    textstr = '\n'.join((
        f"min value = {min_value:0,}",
        f"max value = {max_value:0,}",
        f"mean value = {mean_value:0,}"))
    
    # define box style
    props = dict(boxstyle='round', facecolor='blue', alpha=0.2)

    # place text box on the right with x and y coordinates
    ax.text(0.75, 0.6, textstr, transform=ax.transAxes, fontsize=15,
        verticalalignment='center', bbox=props)

    
    if feature == "market_value_€":
        
        import matplotlib.ticker as plticker
        
        plt.xticks(rotation='vertical')

        #set tick every 10 Mio €
        tick_spacing = 10000000
        loc = plticker.MultipleLocator(tick_spacing)
        ax.xaxis.set_major_locator(loc)
        
        plt.legend(prop={'size': 15})
        plt.show();
    
    else:
        plt.legend(prop={'size': 15})
        plt.show();

# %% [markdown]
# ## Target variable - market value

# %% [markdown]
# ### Field Players

# %%
df_fp["market_value_€"].describe()
# Out:
# count       10979.000
# mean      2907293.469
# std       8017991.462
# min         25000.000
# 25%        325000.000
# 50%        625000.000
# 75%       1800000.000
# max     180000000.000
# Name: market_value_€, dtype: float64

# %%
plot_hist (df_fp, "market_value_€", "Distribution of market values in €")

# %%
sns.boxplot(df_fp["market_value_€"]);

# %% [markdown]
# ##### build function upon z-score in order to identify outliers and get an indicator, where to truncate the dataframe in the future, if outliers should be excluded

# %%
def detect_outlier(df, feature):
    
    outliers=[]
    # standard threshold is 3
    threshold=3
    mean = df[f"{feature}"].mean()
    std = df[f"{feature}"].std()
    
    
    for i in df[f"{feature}"]:
        z_score= (i - mean)/std 
        if np.abs(z_score) > threshold:
            outliers.append(i)
    
    print ("For feature","\033[1m" + feature + "\033[0m","there are outliers:")
    print (len(outliers))
    if len(outliers) > 50: 
        print ("Truncate dataframe at:")
        print (min(outliers))
    else:
        pass

# %%
detect_outlier (df_fp, "market_value_€")
# Out:
# For feature market_value_€ there are outliers:
# 232
# Truncate dataframe at:
# 27000000.0

# %%
plot_hist (df_fp, "overall", "Distribution of overall ratings")

# %% [markdown]
# ### Goalkeepers

# %%
df_gk["market_value_€"].describe()
# Out:
# count       1406.000
# mean     1481909.673
# std      5211826.791
# min        25000.000
# 25%       150000.000
# 50%       325000.000
# 75%       800000.000
# max     80000000.000
# Name: market_value_€, dtype: float64

# %%
plot_hist (df_gk, "market_value_€", "Distribution of market values in €")

# %%
sns.boxplot(df_gk["market_value_€"]);

# %%
detect_outlier (df_gk, "market_value_€")
# Out:
# For feature market_value_€ there are outliers:
# 17

# %%
plot_hist (df_gk, "overall", "Distribution of overall ratings")

# %% [markdown]
# ## Numerical data
#
# Investigation for fieldplayers is representative for goalkeepers

# %% [markdown]
# ### Explore relationship between overall rating and aggregated ratings

# %%
comp_data1 = df_fp[["overall","pace","shooting","passing","dribbling","defending","physic"]]

# %% [markdown]
# ###### building two functions, 1. for plotting pairplots, 2. for plotting a heatmap

# %%
def plot_pair (data):
    sns.pairplot(data, corner=True, diag_kind="kde", kind="reg", plot_kws={'line_kws':{'color':'black'}}, markers="+")

# %%
def plot_heatmap (data):
    
    corrmat = data.corr()
    with sns.axes_style("white"):
        f, ax = plt.subplots(figsize=(16, 10))
        ax.xaxis.tick_top() 
        cmap = sns.color_palette("RdBu_r", 10)
        matrix = np.tril(corrmat)
        
    if len(data.columns) < 15:
    
        sns.set(context="paper", font="monospace", font_scale=2)

        with sns.axes_style("white"):
            heatmap = sns.heatmap(corrmat[(corrmat >= 0.5) | (corrmat <= -0.4)], 
                                  cmap=cmap, vmin=-1, vmax=1, center= 0, square=True, annot=True, 
                                  annot_kws={"size": 12}, fmt='.2g', mask=matrix, linewidths=1, rasterized=True);
    
    elif len(data.columns) <= 30:
        
        sns.set(context="paper", font="monospace", font_scale=1.5)
        
        with sns.axes_style("white"):
            heatmap = sns.heatmap(corrmat[(corrmat >= 0.5) | (corrmat <= -0.4)], 
                                  cmap=cmap, vmin=-1, vmax=1, center= 0, square=True, annot=True, 
                                  annot_kws={"size": 10}, fmt='.1g', mask=matrix, linewidths=1, rasterized=True);
    
    else:
        
        sns.set(context="paper", font="monospace", font_scale=1)

        with sns.axes_style("white"):
            heatmap = sns.heatmap(corrmat[(corrmat >= 0.5) | (corrmat <= -0.4)], 
                                  cmap=cmap, vmin=-1, vmax=1, center= 0, square=True, annot=True, 
                                  annot_kws={"size": 8}, fmt='.1g', mask=matrix, linewidths=1, rasterized=True);

# %%
plot_pair(comp_data1)

# %%
plot_heatmap(comp_data1)

# %% [markdown]
# ### Explore relationship between overall rating and individual attributes

# %%
comp_data2 = df_fp[["overall","attacking_crossing","attacking_finishing","attacking_heading_accuracy",
                    "attacking_short_passing","attacking_volleys","skill_dribbling","skill_curve","skill_fk_accuracy",
                    "skill_long_passing","skill_ball_control","movement_acceleration","movement_sprint_speed",
                    "movement_agility","movement_reactions","movement_balance","power_shot_power","power_jumping",
                    "power_stamina","power_strength","power_long_shots","mentality_aggression","mentality_interceptions",
                    "mentality_positioning","mentality_vision","mentality_penalties","mentality_composure",
                    "defending_marking","defending_standing_tackle","defending_sliding_tackle"]]

# %%
plot_heatmap(comp_data2)

# %% [markdown]
# ### Explore relationship between aggregated ratings and individual attributes

# %%
comp_data3 = df_fp[["pace","shooting","passing","dribbling","defending","physic","attacking_crossing",
                    "attacking_finishing","attacking_heading_accuracy",
                    "attacking_short_passing","attacking_volleys","skill_dribbling","skill_curve","skill_fk_accuracy",
                    "skill_long_passing","skill_ball_control","movement_acceleration","movement_sprint_speed",
                    "movement_agility","movement_reactions","movement_balance","power_shot_power","power_jumping",
                    "power_stamina","power_strength","power_long_shots","mentality_aggression","mentality_interceptions",
                    "mentality_positioning","mentality_vision","mentality_penalties","mentality_composure",
                    "defending_marking","defending_standing_tackle","defending_sliding_tackle"]]

# %%
plot_heatmap(comp_data3)

# %%
# only numericals
df_numerical = df_fp.select_dtypes(exclude = ["O"])
print("{} numerical features :\n{}".format(len(df_numerical.columns), df_numerical.columns.tolist()))
# Out:
# 76 numerical features :
# ['market_value_€', 'year_of_birth', 'player_age', 'height_cm', 'weight_kg', 'divison', 'national_team_current_or_past', 'current_national_player', 'no_current_national_player', 'national_team_appearances', 'international_reputation', 'overall', 'potential', 'weak_foot', 'skill_moves', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots', 'mentality_aggression', 'mentality_interceptions', 'mentality_positioning', 'mentality_vision', 'mentality_penalties', 'mentality_composure', 'defending_marking', 'defending_standing_tackle', 'defending_sliding_tackle', 'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb']

# %% [markdown]
# ##### plot histograms for all numericals

# %%
for i in list(df_numerical.columns):
    plot_hist (df_numerical, f"{i}", "Distribution")

# %% [markdown]
# ##### investigation of histograms gives the information that several numerical features are actually categorical: <br>
#
# - divison
# - national_team_current_or_past
# - current_national_player
# - no_current_national_player
# - international_reputation
# - weak_foot
# - skill_moves

# %% [markdown]
# build a function to convert these numericals to categoricals

# %%
def num_to_cat_conv_fp(df):
    df["divison"] = df["divison"].astype("object")
    df["national_team_current_or_past"] = df["national_team_current_or_past"].astype("object")
    df["current_national_player"] = df["current_national_player"].astype("object")
    df["no_current_national_player"] = df["no_current_national_player"].astype("object")
    df["international_reputation"] = df["international_reputation"].astype("object")
    df["weak_foot"] = df["weak_foot"].astype("object")
    df["skill_moves"] = df["skill_moves"].astype("object")
    return df

def num_to_cat_conv_gk(df):
    df["divison"] = df["divison"].astype("object")
    df["national_team_current_or_past"] = df["national_team_current_or_past"].astype("object")
    df["current_national_player"] = df["current_national_player"].astype("object")
    df["no_current_national_player"] = df["no_current_national_player"].astype("object")
    df["international_reputation"] = df["international_reputation"].astype("object")
    df["weak_foot"] = df["weak_foot"].astype("object")
    df["skill_moves"] = df["skill_moves"].astype("object")
    return df

df_fp = num_to_cat_conv_fp(df_fp)
df_gk = num_to_cat_conv_gk(df_gk)

# %%
df_numerical = df_numerical.drop(["divison","national_team_current_or_past","current_national_player",
                                 "no_current_national_player","international_reputation","weak_foot","skill_moves"],axis=1)

# %%
# outliers in numerical data in general

for i in list(df_numerical.columns):
    detect_outlier(df_numerical, f"{i}")
# Out:
# For feature market_value_€ there are outliers:
# 232
# Truncate dataframe at:
# 27000000.0
# For feature year_of_birth there are outliers:
# 18
# For feature player_age there are outliers:
# 10
# For feature height_cm there are outliers:
# 19
# For feature weight_kg there are outliers:
# 38
# For feature national_team_appearances there are outliers:
# 309
# Truncate dataframe at:
# 56
# For feature overall there are outliers:
# 46
# For feature potential there are outliers:
# 22
# For feature pace there are outliers:
# 84
# Truncate dataframe at:
# 29
# For feature shooting there are outliers:
# 0
# For feature passing there are outliers:
# 13
# For feature dribbling there are outliers:
# 72
# Truncate dataframe at:
# 27
# For feature defending there are outliers:
# 0
# For feature physic there are outliers:
# 33
# For feature attacking_crossing there are outliers:
# 3
# For feature attacking_finishing there are outliers:
# 0
# For feature attacking_heading_accuracy there are outliers:
# 8
# For feature attacking_short_passing there are outliers:
# 104
# Truncate dataframe at:
# 25
# For feature attacking_volleys there are outliers:
# 0
# For feature skill_dribbling there are outliers:
# 83
# Truncate dataframe at:
# 17
# For feature skill_curve there are outliers:
# 0
# For feature skill_fk_accuracy there are outliers:
# 1
# For feature skill_long_passing there are outliers:
# 14
# For feature skill_ball_control there are outliers:
# 120
# Truncate dataframe at:
# 26
# For feature movement_acceleration there are outliers:
# 50
# For feature movement_sprint_speed there are outliers:
# 110
# Truncate dataframe at:
# 29
# For feature movement_agility there are outliers:
# 37
# For feature movement_reactions there are outliers:
# 45
# For feature movement_balance there are outliers:
# 13
# For feature power_shot_power there are outliers:
# 24
# For feature power_jumping there are outliers:
# 44
# For feature power_stamina there are outliers:
# 117
# Truncate dataframe at:
# 29
# For feature power_strength there are outliers:
# 28
# For feature power_long_shots there are outliers:
# 0
# For feature mentality_aggression there are outliers:
# 1
# For feature mentality_interceptions there are outliers:
# 0
# For feature mentality_positioning there are outliers:
# 1
# For feature mentality_vision there are outliers:
# 4
# For feature mentality_penalties there are outliers:
# 10
# For feature mentality_composure there are outliers:
# 12
# For feature defending_marking there are outliers:
# 0
# For feature defending_standing_tackle there are outliers:
# 0
# For feature defending_sliding_tackle there are outliers:
# 0
# For feature ls there are outliers:
# 3
# For feature st there are outliers:
# 3
# For feature rs there are outliers:
# 3
# For feature lw there are outliers:
# 8
# For feature lf there are outliers:
# 5
# For feature cf there are outliers:
# 5
# For feature rf there are outliers:
# 5
# For feature rw there are outliers:
# 8
# For feature lam there are outliers:
# 29
# For feature cam there are outliers:
# 29
# For feature ram there are outliers:
# 29
# For feature lm there are outliers:
# 25
# For feature lcm there are outliers:
# 19
# For feature cm there are outliers:
# 19
# For feature rcm there are outliers:
# 19
# For feature rm there are outliers:
# 25
# For feature lwb there are outliers:
# 1
# For feature ldm there are outliers:
# 1
# For feature cdm there are outliers:
# 1
# For feature rdm there are outliers:
# 1
# For feature rwb there are outliers:
# 1
# For feature lb there are outliers:
# 0
# For feature lcb there are outliers:
# 0
# For feature cb there are outliers:
# 0
# For feature rcb there are outliers:
# 0
# For feature rb there are outliers:
# 0

# %% [markdown]
# we don't have that much outliers overall --> most of them should also be gone, once the dataframe is truncated of all "superstars", due to them having high numbers in the attributes

# %% [markdown]
# ## Categorical variables
#
# as for numerical data, investigation for fieldplayers is representative for goalkeepers

# %%
df_fp.head(1)
# Out:
#    market_value_€   player_name                       long_name  \
# 0   112000000.000  Lionel Messi  Lionel Andrés Messi Cuccittini
#
#    year_of_birth  player_age  height_cm  weight_kg nationality main_position  \
# 0           1987          32        170         72   Argentina   Rechtsaußen
#
#   all_positions          club  league divison national_team_current_or_past  \
# 0    RW, CF, ST  FC Barcelona  LaLiga       1                             1
#
#   national_team_country current_national_player no_current_national_player  \
# 0           Argentinien                       1                          0
#
#    national_team_appearances international_reputation  overall  potential  \
# 0                        138                        5       94         94
#
#   preferred_foot weak_foot skill_moves   work_rate  pace  shooting  passing  \
# 0           Left         4           4  Medium/Low    87        92       92
#
#    dribbling  defending  physic  \
# 0         96         39      66
#
#                                        player_traits  attacking_crossing  \
# 0  Beat Offside Trap, Argues with Officials, Earl...                  88
#
#    attacking_finishing  attacking_heading_accuracy  attacking_short_passing  \
# 0                   95                          70                       92
#
#    attacking_volleys  skill_dribbling  skill_curve  skill_fk_accuracy  \
# 0                 88               97           93                 94
#
#    skill_long_passing  skill_ball_control  movement_acceleration  \
# 0                  92                  96                     91
#
#    movement_sprint_speed  movement_agility  movement_reactions  \
# 0                     84                93                  95
#
#    movement_balance  power_shot_power  power_jumping  power_stamina  \
# 0                95                86             68             75
#
#    power_strength  power_long_shots  mentality_aggression  \
# 0              68                94                    48
#
#    mentality_interceptions  mentality_positioning  mentality_vision  \
# 0                       40                     94                94
#
#    mentality_penalties  mentality_composure  defending_marking  \
# 0                   75                   96                 33
#
#    defending_standing_tackle  defending_sliding_tackle  ls  st  rs  lw  lf  \
# 0                         37                        26  89  89  89  93  93
#
#    cf  rf  rw  lam  cam  ram  lm  lcm  cm  rcm  rm  lwb  ldm  cdm  rdm  rwb  \
# 0  93  93  93   93   93   93  92   87  87   87  92   68   66   66   66   68
#
#    lb  lcb  cb  rcb  rb
# 0  63   52  52   52  63

# %% [markdown]
# Categories needed to be investigated upon:
# - nationality
# - main
# - all_positions (doesn't apply for GK)
# - club
# - league
# - national_team_country
# - preferred_foot
# - work_rate (doesn't apply for GK)
# - traits
# - divison
# - national_team_current_or_past
# - current_national_player
# - no_current_national_player
# - international_reputation
# - weak_foot
# - skill_moves

# %%
df_fp_cat = df_fp[["nationality","main_position","all_positions","club","league","national_team_country",
                   "preferred_foot","work_rate","player_traits","divison","national_team_current_or_past",
                  "current_national_player","no_current_national_player","international_reputation",
                   "weak_foot","skill_moves"]]
df_gk_cat = df_gk[["nationality","main_position","club","league","national_team_country",
                   "preferred_foot","player_traits","divison","national_team_current_or_past",
                  "current_national_player","no_current_national_player","international_reputation",
                   "weak_foot","skill_moves"]]

# %%
def count_cat_uniques(df):
    for i in list(df.columns):
        print ("\033[1m" + i + "\033[0m","got uniques:",df[f"{i}"].nunique())

# %%
count_cat_uniques(df_fp_cat)
# Out:
# nationality got uniques: 148
# main_position got uniques: 15
# all_positions got uniques: 569
# club got uniques: 571
# league got uniques: 34
# national_team_country got uniques: 154
# preferred_foot got uniques: 2
# work_rate got uniques: 9
# player_traits got uniques: 763
# divison got uniques: 2
# national_team_current_or_past got uniques: 2
# current_national_player got uniques: 2
# no_current_national_player got uniques: 2
# international_reputation got uniques: 5
# weak_foot got uniques: 5
# skill_moves got uniques: 4

# %%
count_cat_uniques(df_gk_cat)
# Out:
# nationality got uniques: 82
# main_position got uniques: 1
# club got uniques: 561
# league got uniques: 34
# national_team_country got uniques: 89
# preferred_foot got uniques: 2
# player_traits got uniques: 80
# divison got uniques: 2
# national_team_current_or_past got uniques: 2
# current_national_player got uniques: 2
# no_current_national_player got uniques: 2
# international_reputation got uniques: 5
# weak_foot got uniques: 5
# skill_moves got uniques: 1

# %%
def plot_count_cat(df, feature):
    sns.set(style="darkgrid")
    
    fig, ax = plt.subplots(figsize=(15,5))
    sns.countplot(x=f"{feature}", alpha=0.7, data=df)
    plt.xticks(rotation=90)
    plt.tight_layout()

# %%
# drop categories with high unique count for the count plot loop

df_fp_cat_loop = df_fp_cat.drop(["nationality","club", "all_positions","national_team_country","player_traits"],axis=1)

for i in list(df_fp_cat_loop.columns):
    plot_count_cat (df_fp_cat_loop, f"{i}")

# %% [markdown]
# ##### Save

# %%
df_fp.to_csv('data/fp_data_v2.csv')
df_gk.to_csv('data/gk_data_v2.csv')

# %% [markdown]
# # Work to follow
# ##### thoughts for feature engineering
#
# - aggregate nationality and national teams into continents
# - make some sort of ranking with club, like "top 50 in market value", etc. maybe use for "superstars"
# - convert all positions into some sort of "the more positions able to play the more flexible the player is"
# - investigate what work rate, international reputation and skill_moves refer to
# - investigate upon player traits and aggregate into broader categories
# - investigate upon national team appearance
#
# ##### further work
# - truncate dataframe
# - do second EDA, after dataframe has been truncated and features have been engineered
